# %% [markdown]
# ### Installing https://github.com/T-Strojny/geco3/tree/main

# %%
# !pip install git+https://github.com/T-Strojny/geco3.git

# %% [markdown]
# Importing libraries, setting seed

# %%
from geco3 import basefunctions, attrgenfunct, contdepfunct
from geco3 import generator, corruptor

import random
random.seed(42)

# %% [markdown]
# Unicode used for generation, available options --> # http://docs.python.org/library/codecs.html#standard-encodings

# %%
unicode_encoding_used = 'utf-8'

# %% [markdown]
# rec_id_attr_name --> prefix of the ID column

# %%
rec_id_attr_name = 'rec-id'
out_file_name = 'GECO3_CORRUPTION_RESULT_2.csv'

# %% [markdown]
# set how many records and new corrupted records to generate

# %%
num_org_rec = 1000
num_dup_rec = 1000

# %%
max_duplicate_per_record = 3
num_duplicates_distribution = 'zipf'

# %%
max_modification_per_attr = 1
num_modification_per_record = 5

# %%
basefunctions.check_unicode_encoding_exists(unicode_encoding_used)

# %% [markdown]
# ### Creating attributes

# %% [markdown]
# Data for female given names --> https://www.kaggle.com/datasets/djablo/list-of-polish-first-and-last-names?resource=download
#
# Surnames generated by AI

# %%
given_name_attr = generator.GenerateFreqAttribute(
                          attribute_name = 'given-name',
                          freq_file_name = '/content/polish_female_firstnames.csv',
                          has_header_line = True,
                          unicode_encoding = unicode_encoding_used
                          )

# %%
surname_attr = generator.GenerateFreqAttribute(
                          attribute_name = 'surname',
                          freq_file_name = '/content/polish_female_surnames.csv',
                          has_header_line = True,
                          unicode_encoding = unicode_encoding_used
                          )

# %% [markdown]
# postcode data --> https://www.kaggle.com/datasets/ravikanth/poland-postal-codes-zip-state-counties-districts?select=pl_state_district_mapping.csv

# %%
postcode_attr = generator.GenerateFreqAttribute(
                          attribute_name = 'postcode',
                          freq_file_name = '/content/pl_state_district_mapping.csv',
                          has_header_line = True,
                          unicode_encoding = unicode_encoding_used
                          )

# %% [markdown]
# custom function created for the example

# %%
phone_number_attribute = generator.GenerateFuncAttribute(
                                  attribute_name = 'telephone-number',
                                  function = attrgenfunct.generate_phone_number_poland
                      )

# %%
credit_card_attr =  \
    generator.GenerateFuncAttribute(attribute_name = 'credit-card-number',
                       function = attrgenfunct.generate_credit_card_number)

age_uniform_attr = \
    generator.GenerateFuncAttribute(attribute_name = 'age-uniform',
                       function = attrgenfunct.generate_uniform_age,
                       parameters = [0,100])

# %%
income_normal_attr = \
    generator.GenerateFuncAttribute(attribute_name = 'income-normal',
                       function = attrgenfunct.generate_normal_value,
                       parameters = [50000,20000, 0, 1000000, 'float2'])

# %%
city_attr = generator.GenerateFreqAttribute(
                      attribute_name = "city",
                      freq_file_name = "/content/city_freq.csv",
                      has_header = True,
                      unicode_encoding = unicode_encoding_used,
                      )

# %% [markdown]
# ### Creating variables for corruptor

# %%
edit_corruptor = corruptor.CorruptValueEdit(
          position_function = corruptor.position_mod_normal,
          char_set_funct = basefunctions.char_set_ascii,
          insert_prob = 0.5,
          delete_prob = 0.5,
          substitute_prob = 0.0,
          transpose_prob = 0.0
          )

edit_corruptor2 = corruptor.CorruptValueEdit(\
          position_function = corruptor.position_mod_uniform,
          char_set_funct = basefunctions.char_set_ascii,
          insert_prob = 0.25,
          delete_prob = 0.25,
          substitute_prob = 0.25,
          transpose_prob = 0.25
          )

# %%
surname_misspell_corruptor = \
    corruptor.CorruptCategoricalValue(\
          lookup_file_name = '/content/misspell_polish_surnames.csv',
          has_header_line = True,
          unicode_encoding = unicode_encoding_used)

# %%
ocr_corruptor = corruptor.CorruptValueOCR(
          position_function = corruptor.position_mod_normal,
          lookup_file_name = '/content/ocr-variations.csv',
          has_header_line = True,
          unicode_encoding = unicode_encoding_used
          )

keyboard_corruptor = corruptor.CorruptValueKeyboard(
          position_function = corruptor.position_mod_normal,
          row_prob = 0.5,
          col_prob = 0.5
          )

phonetic_corruptor = corruptor.CorruptValuePhonetic(
          lookup_file_name = '/content/phonetic-variations.csv',
          has_header_line = True,
          unicode_encoding = unicode_encoding_used
          )

missing_val_corruptor = corruptor.CorruptMissingValue()

postcode_missing_val_corruptor = corruptor.CorruptMissingValue(
       missing_val='missing'
       )

given_name_missing_val_corruptor = corruptor.CorruptMissingValue(
       missing_value='unknown'
       )

# %%
attr_name_list = ['given-name', 'surname', 'postcode', 'city',
                  'telephone-number', 'credit-card-number', 'income-normal',
                  'age-uniform']

attr_data_list = [given_name_attr, surname_attr, postcode_attr, city_attr, phone_number_attribute,
                  credit_card_attr, age_uniform_attr, income_normal_attr]

# %% [markdown]
# Generating dataset

# %%
test_data_generator = generator.GenerateDataSet(
                                          output_file_name = out_file_name,
                                          write_header_line = True,
                                          rec_id_attr_name = rec_id_attr_name,
                                          number_of_records = num_org_rec,
                                          attribute_name_list = attr_name_list,
                                          attribute_data_list = attr_data_list,
                                          unicode_encoding = unicode_encoding_used
                                          )

# %% [markdown]
# set probability of corrupting single record, must sum to 1

# %%
attr_mod_prob_dictionary = {'given-name':0.2,
                            'surname':0.2,
                            'postcode':0.1,
                            'city':0.1,
                            'income-normal': 0.1,
                            'telephone-number':0.10,
                            'credit-card-number':0.15,
                            'age-uniform':0.05
                            }

# %% [markdown]
# Set probabilities of which corruptor to use, must sum to 1

# %%
attr_mod_data_dictionary = {'surname':[(0.1, surname_misspell_corruptor),
                                       (0.1, ocr_corruptor),
                                       (0.1, keyboard_corruptor),
                                       (0.7, phonetic_corruptor)],
                            'given-name':[(0.1, edit_corruptor2),
                                          (0.1, ocr_corruptor),
                                          (0.1, keyboard_corruptor),
                                          (0.7, phonetic_corruptor)],
                            'postcode':[(0.8, keyboard_corruptor),
                                        (0.2, postcode_missing_val_corruptor)],
                            'city':[(0.1, edit_corruptor),
                                    (0.1, missing_val_corruptor),
                                    (0.4, keyboard_corruptor),
                                    (0.4, phonetic_corruptor)],
                            'income-normal':[(0.4, missing_val_corruptor),
                                             (0.6, edit_corruptor)],
                            'age-uniform':[(1.0, edit_corruptor2)],
                            'telephone-number':[(1.0, missing_val_corruptor)],
                            'credit-card-number':[(1.0, edit_corruptor)]}

# %% [markdown]
# corrupt dataset

# %%
test_data_corruptor = corruptor.CorruptDataSet(number_of_org_records = num_org_rec,
                                                number_of_mod_records = num_dup_rec,
                                                attribute_name_list = attr_name_list,
                                                max_num_dup_per_rec = max_duplicate_per_record,
                                                num_dup_dist = num_duplicates_distribution,
                                                max_num_mod_per_attr = max_modification_per_attr,
                                                num_mod_per_rec = num_modification_per_record,
                                                attr_mod_prob_dict = attr_mod_prob_dictionary,
                                                attr_mod_data_dict = attr_mod_data_dictionary
                                                )

# %% [markdown]
# Run everything

# %%
rec_dict = test_data_generator.generate()

assert len(rec_dict) == num_org_rec  # Check the number of generated records

# Corrupt (modify) the original records into duplicate records
#
rec_dict = test_data_corruptor.corrupt_records(rec_dict)

assert len(rec_dict) == num_org_rec+num_dup_rec # Check total number of records

# Write generate data into a file
#
test_data_generator.write()
# Out:
# Streaming output truncated to the last 5000 lines.
#       Modified attribute value: ''
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Amelia'
#       Modified attribute value: 'Amelja'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-332'
#       Modified attribute value: '60-33w'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0465 7482 4154 5876'
#       Modified attribute value: '0465 7482 4154 58576'
# Original record:
#   ['Amelia', 'Nowicka', '60-332', 'Gniezno', '539205146', '0465 7482 4154 5876', '34436.26', '82']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number,):
#   ['Amelja', 'Noicka', '60-33w', 'Gniezno', '', '0465 7482 4154 58576', '34436.26', '82']
# 829 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-487-org": rec-487-dup-1
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0465 7482 4154 5876'
#       Modified attribute value: '0465 74832 4154 5876'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Nowicka'
#       Modified attribute value: 'Nowiccka'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-332'
#       Modified attribute value: '60-322'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Amelia'
#       Modified attribute value: 'Amelya'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Gniezno'
#       Modified attribute value: 'Gniesno'
# Original record:
#   ['Amelia', 'Nowicka', '60-332', 'Gniezno', '539205146', '0465 7482 4154 5876', '34436.26', '82']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Amelya', 'Nowiccka', '60-322', 'Gniesno', '539205146', '0465 74832 4154 5876', '34436.26', '82']
# 830 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-627-org"
#   Generate identifier for duplicate record based on "rec-627-org": rec-627-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Daria'
#       Modified attribute value: 'Darya'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Sadowska'
#       Modified attribute value: 'Sadoska'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Gniezno'
#       Modified attribute value: 'Gniejno'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-654'
#       Modified attribute value: '61-65e'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '693228360'
#       Modified attribute value: ''
# Original record:
#   ['Daria', 'Sadowska', '61-654', 'Gniezno', '693228360', '8569 4478 9449 3073', '34231.53', '49']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in telephone-number,):
#   ['Darya', 'Sadoska', '61-65e', 'Gniejno', '', '8569 4478 9449 3073', '34231.53', '49']
# 831 of 1000 duplicate records generated so far
#
#
# Generating 3 modified (duplicate) records for record "rec-692-org"
#   Generate identifier for duplicate record based on "rec-692-org": rec-692-dup-0
#   Selected attribute for modification: surname
#     Selected corruptor: Keybord value
#       Original attribute value: 'Wojciechowska'
#       Modified attribute value: 'Wojciecbowska'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Sabina'
#       Modified attribute value: 'Sapina'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0628 0502 2046 2752'
#       Modified attribute value: '0628 0502 2046 252'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-119'
#       Modified attribute value: '60-129'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '28'
#       Modified attribute value: '48'
# Original record:
#   ['Sabina', 'Wojciechowska', '60-119', 'Konin', '455669579', '0628 0502 2046 2752', '56466.70', '28']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in credit-card-number, 1 in age-uniform,):
#   ['Sapina', 'Wojciecbowska', '60-129', 'Konin', '455669579', '0628 0502 2046 252', '56466.70', '48']
# 832 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-692-org": rec-692-dup-1
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-119'
#       Modified attribute value: '60-11o'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0628 0502 2046 2752'
#       Modified attribute value: '0628 0502 2046 752'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wojciechowska'
#       Modified attribute value: 'Wojciechoska'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '56466.70'
#       Modified attribute value: ''
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '455669579'
#       Modified attribute value: ''
# Original record:
#   ['Sabina', 'Wojciechowska', '60-119', 'Konin', '455669579', '0628 0502 2046 2752', '56466.70', '28']
# Record with 5 modified attributes
# (1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number, 1 in income-normal,):
#   ['Sabina', 'Wojciechoska', '60-11o', 'Konin', '', '0628 0502 2046 752', '', '28']
# 833 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-692-org": rec-692-dup-2
#   Selected attribute for modification: given-name
#     Selected corruptor: Edit operation
#       Original attribute value: 'Sabina'
#       Modified attribute value: 'Sabnia'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wojciechowska'
#       Modified attribute value: 'Wojciechowscka'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '28'
#       Modified attribute value: '2'
#   Selected attribute for modification: city
#     Selected corruptor: Missing value
#       Original attribute value: 'Konin'
#       Modified attribute value: ''
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-119'
#       Modified attribute value: '60-11i'
# Original record:
#   ['Sabina', 'Wojciechowska', '60-119', 'Konin', '455669579', '0628 0502 2046 2752', '56466.70', '28']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in age-uniform,):
#   ['Sabnia', 'Wojciechowscka', '60-11i', '', '455669579', '0628 0502 2046 2752', '56466.70', '2']
# 834 of 1000 duplicate records generated so far
#
#
# Generating 3 modified (duplicate) records for record "rec-676-org"
#   Generate identifier for duplicate record based on "rec-676-org": rec-676-dup-0
#   Selected attribute for modification: surname
#     Selected corruptor: Keybord value
#       Original attribute value: 'Wiśniewska'
#       Modified attribute value: 'Wiśniewsma'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '91'
#       Modified attribute value: '90'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '570027300'
#       Modified attribute value: ''
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '62-010'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Gerda'
#       Modified attribute value: 'Gerta'
# Original record:
#   ['Gerda', 'Wiśniewska', '62-010', 'Poznań', '570027300', '8420 7115 9837 6401', '45149.19', '91']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in age-uniform,):
#   ['Gerta', 'Wiśniewsma', 'missing', 'Poznań', '', '8420 7115 9837 6401', '45149.19', '90']
# 835 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-676-org": rec-676-dup-1
#   Selected attribute for modification: given-name
#     Selected corruptor: Edit operation
#       Original attribute value: 'Gerda'
#       Modified attribute value: 'Gerha'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Posnań'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '8420 7115 9837 6401'
#       Modified attribute value: '8420 7115 9837 64701'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '62-010'
#       Modified attribute value: '62-019'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '45149.19'
#       Modified attribute value: ''
# Original record:
#   ['Gerda', 'Wiśniewska', '62-010', 'Poznań', '570027300', '8420 7115 9837 6401', '45149.19', '91']
# Record with 5 modified attributes
# (1 in given-name, 1 in postcode, 1 in city, 1 in credit-card-number, 1 in income-normal,):
#   ['Gerha', 'Wiśniewska', '62-019', 'Posnań', '570027300', '8420 7115 9837 64701', '', '91']
# 836 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-676-org": rec-676-dup-2
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '62-010'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wiśniewska'
#       Modified attribute value: 'Wiśnieska'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '45149.19'
#       Modified attribute value: ''
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '8420 7115 9837 6401'
#       Modified attribute value: '8420 7115 837 6401'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Gerda'
#       Modified attribute value: 'Geahda'
# Original record:
#   ['Gerda', 'Wiśniewska', '62-010', 'Poznań', '570027300', '8420 7115 9837 6401', '45149.19', '91']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in credit-card-number, 1 in income-normal,):
#   ['Geahda', 'Wiśnieska', 'missing', 'Poznań', '570027300', '8420 7115 837 6401', '', '91']
# 837 of 1000 duplicate records generated so far
#
#
# Generating 3 modified (duplicate) records for record "rec-431-org"
#   Generate identifier for duplicate record based on "rec-431-org": rec-431-dup-0
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wasilewska'
#       Modified attribute value: 'Wasileska'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Stella'
#       Modified attribute value: 'Stela'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '64-412'
#       Modified attribute value: '64-r12'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Posnań'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '4209 1299 7102 1908'
#       Modified attribute value: '4209 12997102 1908'
# Original record:
#   ['Stella', 'Wasilewska', '64-412', 'Poznań', '791546602', '4209 1299 7102 1908', '58605.25', '79']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Stela', 'Wasileska', '64-r12', 'Posnań', '791546602', '4209 12997102 1908', '58605.25', '79']
# 838 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-431-org": rec-431-dup-1
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '64-412'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Poznwń'
#   Selected attribute for modification: given-name
#     Selected corruptor: Keybord value
#       Original attribute value: 'Stella'
#       Modified attribute value: 'Stekla'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '79'
#       Modified attribute value: '29'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '791546602'
#       Modified attribute value: ''
# Original record:
#   ['Stella', 'Wasilewska', '64-412', 'Poznań', '791546602', '4209 1299 7102 1908', '58605.25', '79']
# Record with 5 modified attributes
# (1 in given-name, 1 in postcode, 1 in city, 1 in telephone-number, 1 in age-uniform,):
#   ['Stekla', 'Wasilewska', 'missing', 'Poznwń', '', '4209 1299 7102 1908', '58605.25', '29']
# 839 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-431-org": rec-431-dup-2
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '64-412'
#       Modified attribute value: '64-4q2'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '4209 1299 7102 1908'
#       Modified attribute value: '4209 12997102 1908'
#   Selected attribute for modification: surname
#     Selected corruptor: OCR value
#       Original attribute value: 'Wasilewska'
#       Modified attribute value: 'Wasilevvska'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '79'
#       Modified attribute value: '279'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Stella'
#       Modified attribute value: 'Stela'
# Original record:
#   ['Stella', 'Wasilewska', '64-412', 'Poznań', '791546602', '4209 1299 7102 1908', '58605.25', '79']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in credit-card-number, 1 in age-uniform,):
#   ['Stela', 'Wasilevvska', '64-4q2', 'Poznań', '791546602', '4209 12997102 1908', '58605.25', '279']
# 840 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-295-org"
#   Generate identifier for duplicate record based on "rec-295-org": rec-295-dup-0
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1265 7675 7822 5132'
#       Modified attribute value: '1265 7675 7822 132'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '89-310'
#       Modified attribute value: '89-3q0'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Baranowska'
#       Modified attribute value: 'Baranovskiea'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Maryla'
#       Modified attribute value: 'Mariela'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Piła'
#       Modified attribute value: 'Piłz'
# Original record:
#   ['Maryla', 'Baranowska', '89-310', 'Piła', '669036289', '1265 7675 7822 5132', '44744.28', '65']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Mariela', 'Baranovskiea', '89-3q0', 'Piłz', '669036289', '1265 7675 7822 132', '44744.28', '65']
# 841 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-085-org"
#   Generate identifier for duplicate record based on "rec-085-org": rec-085-dup-0
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-595'
#       Modified attribute value: '60-585'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Lis'
#       Modified attribute value: 'List'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '44069.19'
#       Modified attribute value: ''
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Posnań'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '53'
#       Modified attribute value: '35'
# Original record:
#   ['Eliza', 'Lis', '60-595', 'Poznań', '667198554', '6564 0905 1486 5986', '44069.19', '53']
# Record with 5 modified attributes
# (1 in surname, 1 in postcode, 1 in city, 1 in income-normal, 1 in age-uniform,):
#   ['Eliza', 'List', '60-585', 'Posnań', '667198554', '6564 0905 1486 5986', '', '35']
# 842 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-356-org"
#   Generate identifier for duplicate record based on "rec-356-org": rec-356-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Fryderyka'
#       Modified attribute value: 'Fryderycka'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '64680.85'
#       Modified attribute value: ''
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '63-014'
#       Modified attribute value: '63-024'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '4137 8047 7169 4688'
#       Modified attribute value: '4137 80747 7169 4688'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Konin'
#       Modified attribute value: 'Komin'
# Original record:
#   ['Fryderyka', 'Adamska', '63-014', 'Konin', '797629833', '4137 8047 7169 4688', '64680.85', '23']
# Record with 5 modified attributes
# (1 in given-name, 1 in postcode, 1 in city, 1 in credit-card-number, 1 in income-normal,):
#   ['Fryderycka', 'Adamska', '63-024', 'Komin', '797629833', '4137 80747 7169 4688', '', '23']
# 843 of 1000 duplicate records generated so far
#
#
# Generating 3 modified (duplicate) records for record "rec-502-org"
#   Generate identifier for duplicate record based on "rec-502-org": rec-502-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Edit operation
#       Original attribute value: 'Jowita'
#       Modified attribute value: 'Jowtia'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '8495 2743 1634 8154'
#       Modified attribute value: '8495 2743 81634 8154'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '19'
#       Modified attribute value: '019'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Leszno'
#       Modified attribute value: 'Lejzno'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-159'
#       Modified attribute value: '60-q59'
# Original record:
#   ['Jowita', 'Młynarczyk', '60-159', 'Leszno', '881441529', '8495 2743 1634 8154', '19420.33', '19']
# Record with 5 modified attributes
# (1 in given-name, 1 in postcode, 1 in city, 1 in credit-card-number, 1 in age-uniform,):
#   ['Jowtia', 'Młynarczyk', '60-q59', 'Lejzno', '881441529', '8495 2743 81634 8154', '19420.33', '019']
# 844 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-502-org": rec-502-dup-1
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-159'
#       Modified attribute value: '60-259'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '8495 2743 1634 8154'
#       Modified attribute value: '8495 82743 1634 8154'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Młynarczyk'
#       Modified attribute value: 'Młynarkzyk'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Jowita'
#       Modified attribute value: 'Jowida'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '19420.33'
#       Modified attribute value: ''
# Original record:
#   ['Jowita', 'Młynarczyk', '60-159', 'Leszno', '881441529', '8495 2743 1634 8154', '19420.33', '19']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in credit-card-number, 1 in income-normal,):
#   ['Jowida', 'Młynarkzyk', '60-259', 'Leszno', '881441529', '8495 82743 1634 8154', '', '19']
# 845 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-502-org": rec-502-dup-2
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Młynarczyk'
#       Modified attribute value: 'Młynarctsyk'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '8495 2743 1634 8154'
#       Modified attribute value: '8495 2743 16374 8154'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-159'
#       Modified attribute value: '60-158'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Leszno'
#       Modified attribute value: 'Leszni'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '19420.33'
#       Modified attribute value: ''
# Original record:
#   ['Jowita', 'Młynarczyk', '60-159', 'Leszno', '881441529', '8495 2743 1634 8154', '19420.33', '19']
# Record with 5 modified attributes
# (1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number, 1 in income-normal,):
#   ['Jowita', 'Młynarctsyk', '60-158', 'Leszni', '881441529', '8495 2743 16374 8154', '', '19']
# 846 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-903-org"
#   Generate identifier for duplicate record based on "rec-903-org": rec-903-dup-0
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-627'
#       Modified attribute value: '61-t27'
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Aurelia'
#       Modified attribute value: 'Aurel:a'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6654 1895 8231 5369'
#       Modified attribute value: '6654 1895 8231 65369'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '49'
#       Modified attribute value: '94'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Andrzejewska'
#       Modified attribute value: 'Andrzejewjka'
# Original record:
#   ['Aurelia', 'Andrzejewska', '61-627', 'Poznań', '519425251', '6654 1895 8231 5369', '57152.91', '49']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in credit-card-number, 1 in age-uniform,):
#   ['Aurel:a', 'Andrzejewjka', '61-t27', 'Poznań', '519425251', '6654 1895 8231 65369', '57152.91', '94']
# 847 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-903-org": rec-903-dup-1
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '519425251'
#       Modified attribute value: ''
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Andrzejewska'
#       Modified attribute value: 'Andrzejewjka'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6654 1895 8231 5369'
#       Modified attribute value: '6654 1895 68231 5369'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '49'
#       Modified attribute value: '449'
#   Selected attribute for modification: city
#     Selected corruptor: Missing value
#       Original attribute value: 'Poznań'
#       Modified attribute value: ''
# Original record:
#   ['Aurelia', 'Andrzejewska', '61-627', 'Poznań', '519425251', '6654 1895 8231 5369', '57152.91', '49']
# Record with 5 modified attributes
# (1 in surname, 1 in city, 1 in telephone-number, 1 in credit-card-number, 1 in age-uniform,):
#   ['Aurelia', 'Andrzejewjka', '61-627', '', '', '6654 1895 68231 5369', '57152.91', '449']
# 848 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-231-org"
#   Generate identifier for duplicate record based on "rec-231-org": rec-231-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Edit operation
#       Original attribute value: 'Łucja'
#       Modified attribute value: 'Łuja'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-526'
#       Modified attribute value: '61-5q6'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Kalisz'
#       Modified attribute value: 'Kalistz'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Cieślicka'
#       Modified attribute value: 'Cieślika'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '3154 0854 2319 3346'
#       Modified attribute value: '3154 0854 2319 30346'
# Original record:
#   ['Łucja', 'Cieślicka', '61-526', 'Kalisz', '725270171', '3154 0854 2319 3346', '25182.77', '13']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Łuja', 'Cieślika', '61-5q6', 'Kalistz', '725270171', '3154 0854 2319 30346', '25182.77', '13']
# 849 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-712-org"
#   Generate identifier for duplicate record based on "rec-712-org": rec-712-dup-0
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Kaczmarek'
#       Modified attribute value: 'Kacsmarek'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '735449791'
#       Modified attribute value: ''
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '61-819'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Ligia'
#       Modified attribute value: 'Ligya'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '36984.81'
#       Modified attribute value: ''
# Original record:
#   ['Ligia', 'Kaczmarek', '61-819', 'Gniezno', '735449791', '2957 7321 9890 9540', '36984.81', '44']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in income-normal,):
#   ['Ligya', 'Kacsmarek', 'missing', 'Gniezno', '', '2957 7321 9890 9540', '', '44']
# 850 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-030-org"
#   Generate identifier for duplicate record based on "rec-030-org": rec-030-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Missing value
#       Original attribute value: 'Piła'
#       Modified attribute value: ''
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1265 5320 7906 2833'
#       Modified attribute value: '1265 53 20 7906 2833'
#   Selected attribute for modification: given-name
#     Selected corruptor: Edit operation
#       Original attribute value: 'Irena'
#       Modified attribute value: 'Ireoa'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '534419693'
#       Modified attribute value: ''
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Jankowska'
#       Modified attribute value: 'Jankowstka'
# Original record:
#   ['Irena', 'Jankowska', '60-639', 'Piła', '534419693', '1265 5320 7906 2833', '62118.41', '49']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in telephone-number, 1 in credit-card-number,):
#   ['Ireoa', 'Jankowstka', '60-639', '', '', '1265 53 20 7906 2833', '62118.41', '49']
# 851 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-030-org": rec-030-dup-1
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '62118.41'
#       Modified attribute value: ''
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Piła'
#       Modified attribute value: 'Piłs'
#   Selected attribute for modification: surname
#     Selected corruptor: Keybord value
#       Original attribute value: 'Jankowska'
#       Modified attribute value: 'Jankowzka'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-639'
#       Modified attribute value: '60-649'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1265 5320 7906 2833'
#       Modified attribute value: '1265 532 7906 2833'
# Original record:
#   ['Irena', 'Jankowska', '60-639', 'Piła', '534419693', '1265 5320 7906 2833', '62118.41', '49']
# Record with 5 modified attributes
# (1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number, 1 in income-normal,):
#   ['Irena', 'Jankowzka', '60-649', 'Piłs', '534419693', '1265 532 7906 2833', '', '49']
# 852 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-480-org"
#   Generate identifier for duplicate record based on "rec-480-org": rec-480-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Missing value
#       Original attribute value: 'Gniezno'
#       Modified attribute value: ''
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '695240148'
#       Modified attribute value: ''
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Szewczyk'
#       Modified attribute value: 'Szewchyk'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '5106 3421 9732 1095'
#       Modified attribute value: '5106 3421 9732 105'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Leonia'
#       Modified attribute value: 'Leonya'
# Original record:
#   ['Leonia', 'Szewczyk', '60-851', 'Gniezno', '695240148', '5106 3421 9732 1095', '46408.51', '6']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in telephone-number, 1 in credit-card-number,):
#   ['Leonya', 'Szewchyk', '60-851', '', '', '5106 3421 9732 105', '46408.51', '6']
# 853 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-017-org"
#   Generate identifier for duplicate record based on "rec-017-org": rec-017-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bogna'
#       Modified attribute value: 'Bokna'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Domańska'
#       Modified attribute value: 'Domańscka'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '3559 5602 6886 5105'
#       Modified attribute value: '3559 502 6886 5105'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Leszno'
#       Modified attribute value: 'Leszni'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-248'
#       Modified attribute value: '60-258'
# Original record:
#   ['Bogna', 'Domańska', '60-248', 'Leszno', '797031207', '3559 5602 6886 5105', '49912.44', '79']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Bokna', 'Domańscka', '60-258', 'Leszni', '797031207', '3559 502 6886 5105', '49912.44', '79']
# 854 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-017-org": rec-017-dup-1
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bogna'
#       Modified attribute value: 'Bokna'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Domańska'
#       Modified attribute value: 'Domańjka'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Leszno'
#       Modified attribute value: 'Lezzno'
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '60-248'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '797031207'
#       Modified attribute value: ''
# Original record:
#   ['Bogna', 'Domańska', '60-248', 'Leszno', '797031207', '3559 5602 6886 5105', '49912.44', '79']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in telephone-number,):
#   ['Bokna', 'Domańjka', 'missing', 'Lezzno', '', '3559 5602 6886 5105', '49912.44', '79']
# 855 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-292-org"
#   Generate identifier for duplicate record based on "rec-292-org": rec-292-dup-0
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6090 0887 1737 9530'
#       Modified attribute value: '609 0887 1737 9530'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Witkowska'
#       Modified attribute value: 'Witkowzka'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Piła'
#       Modified attribute value: 'Piłq'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-287'
#       Modified attribute value: '60-2u7'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Blandyna'
#       Modified attribute value: 'Blantyna'
# Original record:
#   ['Blandyna', 'Witkowska', '60-287', 'Piła', '530212606', '6090 0887 1737 9530', '24605.05', '7']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Blantyna', 'Witkowzka', '60-2u7', 'Piłq', '530212606', '609 0887 1737 9530', '24605.05', '7']
# 856 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-292-org": rec-292-dup-1
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '530212606'
#       Modified attribute value: ''
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Witkowska'
#       Modified attribute value: 'Witkowzka'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-287'
#       Modified attribute value: '60-277'
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Blandyna'
#       Modified attribute value: 'Blandvna'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6090 0887 1737 9530'
#       Modified attribute value: '6090 08871737 9530'
# Original record:
#   ['Blandyna', 'Witkowska', '60-287', 'Piła', '530212606', '6090 0887 1737 9530', '24605.05', '7']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number,):
#   ['Blandvna', 'Witkowzka', '60-277', 'Piła', '', '6090 08871737 9530', '24605.05', '7']
# 857 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-311-org"
#   Generate identifier for duplicate record based on "rec-311-org": rec-311-dup-0
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6739 1699 8134 8925'
#       Modified attribute value: '6739 1699 81384 8925'
#   Selected attribute for modification: surname
#     Selected corruptor: Keybord value
#       Original attribute value: 'Bąk'
#       Modified attribute value: 'Bąi'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '10'
#       Modified attribute value: '20'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Andżelika'
#       Modified attribute value: 'Antżelika'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '45420.25'
#       Modified attribute value: ''
# Original record:
#   ['Andżelika', 'Bąk', '60-751', 'Poznań', '784911110', '6739 1699 8134 8925', '45420.25', '10']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in credit-card-number, 1 in income-normal, 1 in age-uniform,):
#   ['Antżelika', 'Bąi', '60-751', 'Poznań', '784911110', '6739 1699 81384 8925', '', '20']
# 858 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-311-org": rec-311-dup-1
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bąk'
#       Modified attribute value: 'Bąck'
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '60-751'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: given-name
#     Selected corruptor: Keybord value
#       Original attribute value: 'Andżelika'
#       Modified attribute value: 'Andżekika'
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Poznsń'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6739 1699 8134 8925'
#       Modified attribute value: '6739 169 8134 8925'
# Original record:
#   ['Andżelika', 'Bąk', '60-751', 'Poznań', '784911110', '6739 1699 8134 8925', '45420.25', '10']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Andżekika', 'Bąck', 'missing', 'Poznsń', '784911110', '6739 169 8134 8925', '45420.25', '10']
# 859 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-786-org"
#   Generate identifier for duplicate record based on "rec-786-org": rec-786-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Edit operation
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Poznń'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '56'
#       Modified attribute value: '65'
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '60-607'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wawrzyniak'
#       Modified attribute value: 'Wawrzyniack'
#   Selected attribute for modification: given-name
#     Selected corruptor: Keybord value
#       Original attribute value: 'Iwonna'
#       Modified attribute value: 'Iw9nna'
# Original record:
#   ['Iwonna', 'Wawrzyniak', '60-607', 'Poznań', '734854329', '8551 7674 6770 9718', '36830.29', '56']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in age-uniform,):
#   ['Iw9nna', 'Wawrzyniack', 'missing', 'Poznń', '734854329', '8551 7674 6770 9718', '36830.29', '65']
# 860 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-264-org"
#   Generate identifier for duplicate record based on "rec-264-org": rec-264-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Zuzanna'
#       Modified attribute value: 'Zujanna'
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '77-470'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Wojciechowska'
#       Modified attribute value: 'Wojciechowstka'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '501131290'
#       Modified attribute value: ''
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '25160.35'
#       Modified attribute value: ''
# Original record:
#   ['Zuzanna', 'Wojciechowska', '77-470', 'Poznań', '501131290', '1386 4684 9080 8075', '25160.35', '81']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in income-normal,):
#   ['Zujanna', 'Wojciechowstka', 'missing', 'Poznań', '', '1386 4684 9080 8075', '', '81']
# 861 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-264-org": rec-264-dup-1
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1386 4684 9080 8075'
#       Modified attribute value: '1386 4684 90820 8075'
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Zuzanna'
#       Modified attribute value: 'Zu2anna'
#   Selected attribute for modification: surname
#     Selected corruptor: Categorial value
#       Original attribute value: 'Wojciechowska'
#       Modified attribute value: 'Wojcichowska'
#   Selected attribute for modification: postcode
#     Selected corruptor: Missing value
#       Original attribute value: '77-470'
#       Modified attribute value: 'missing'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '501131290'
#       Modified attribute value: ''
# Original record:
#   ['Zuzanna', 'Wojciechowska', '77-470', 'Poznań', '501131290', '1386 4684 9080 8075', '25160.35', '81']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number,):
#   ['Zu2anna', 'Wojcichowska', 'missing', 'Poznań', '', '1386 4684 90820 8075', '25160.35', '81']
# 862 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-418-org"
#   Generate identifier for duplicate record based on "rec-418-org": rec-418-dup-0
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '722727955'
#       Modified attribute value: ''
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Krystyna'
#       Modified attribute value: 'Krysdyna'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '9237 6192 9641 0555'
#       Modified attribute value: '92037 6192 9641 0555'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '32'
#       Modified attribute value: '2'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Szczepańska'
#       Modified attribute value: 'Ssczepańska'
# Original record:
#   ['Krystyna', 'Szczepańska', '60-648', 'Szamotuły', '722727955', '9237 6192 9641 0555', '28840.10', '32']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in telephone-number, 1 in credit-card-number, 1 in age-uniform,):
#   ['Krysdyna', 'Ssczepańska', '60-648', 'Szamotuły', '', '92037 6192 9641 0555', '28840.10', '2']
# 863 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-190-org"
#   Generate identifier for duplicate record based on "rec-190-org": rec-190-dup-0
#   Selected attribute for modification: surname
# ...
#       Original attribute value: '5408 1214 7508 8054'
#       Modified attribute value: '5408 1214 758 8054'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Szewczyk'
#       Modified attribute value: 'Sjewczyk'
# Original record:
#   ['Ludmiła', 'Szewczyk', '61-726', 'Leszno', '665237341', '5408 1214 7508 8054', '63408.94', '75']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in credit-card-number, 1 in income-normal,):
#   ['Lucmiła', 'Sjewczyk', '61-726', 'Leszmo', '665237341', '5408 1214 758 8054', '', '75']
# 989 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-528-org"
#   Generate identifier for duplicate record based on "rec-528-org": rec-528-dup-0
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '721021312'
#       Modified attribute value: ''
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '6118 1065 2524 9371'
#       Modified attribute value: '61181065 2524 9371'
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '54776.43'
#       Modified attribute value: ''
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-644'
#       Modified attribute value: '61-654'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Posnań'
# Original record:
#   ['Wirginia', 'Bednarska', '61-644', 'Poznań', '721021312', '6118 1065 2524 9371', '54776.43', '80']
# Record with 5 modified attributes
# (1 in postcode, 1 in city, 1 in telephone-number, 1 in credit-card-number, 1 in income-normal,):
#   ['Wirginia', 'Bednarska', '61-654', 'Posnań', '', '61181065 2524 9371', '', '80']
# 990 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-768-org"
#   Generate identifier for duplicate record based on "rec-768-org": rec-768-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Edit operation
#       Original attribute value: 'Leszno'
#       Modified attribute value: 'Lesno'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Izabella'
#       Modified attribute value: 'Isabella'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '691472463'
#       Modified attribute value: ''
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0597 1468 9802 8855'
#       Modified attribute value: '05971 1468 9802 8855'
#   Selected attribute for modification: surname
#     Selected corruptor: OCR value
#       Original attribute value: 'Nowakowska'
#       Modified attribute value: 'Nowakovvska'
# Original record:
#   ['Izabella', 'Nowakowska', '62-052', 'Leszno', '691472463', '0597 1468 9802 8855', '44552.42', '75']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in telephone-number, 1 in credit-card-number,):
#   ['Isabella', 'Nowakovvska', '62-052', 'Lesno', '', '05971 1468 9802 8855', '44552.42', '75']
# 991 of 1000 duplicate records generated so far
#
#
# Generating 3 modified (duplicate) records for record "rec-814-org"
#   Generate identifier for duplicate record based on "rec-814-org": rec-814-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Dorota'
#       Modified attribute value: 'Doroda'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Brzezińska'
#       Modified attribute value: 'Brshezińska'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '506708056'
#       Modified attribute value: ''
#   Selected attribute for modification: city
#     Selected corruptor: Edit operation
#       Original attribute value: 'Gniezno'
#       Modified attribute value: 'Gniezn'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '9129 6039 6844 6444'
#       Modified attribute value: '9129 6039 6844 64404'
# Original record:
#   ['Dorota', 'Brzezińska', '61-817', 'Gniezno', '506708056', '9129 6039 6844 6444', '36618.71', '46']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in telephone-number, 1 in credit-card-number,):
#   ['Doroda', 'Brshezińska', '61-817', 'Gniezn', '', '9129 6039 6844 64404', '36618.71', '46']
# 992 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-814-org": rec-814-dup-1
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Brzezińska'
#       Modified attribute value: 'Brjezińska'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '9129 6039 6844 6444'
#       Modified attribute value: '9129 6039 68144 6444'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-817'
#       Modified attribute value: '62-817'
#   Selected attribute for modification: given-name
#     Selected corruptor: Keybord value
#       Original attribute value: 'Dorota'
#       Modified attribute value: 'Dorora'
#   Selected attribute for modification: city
#     Selected corruptor: Missing value
#       Original attribute value: 'Gniezno'
#       Modified attribute value: ''
# Original record:
#   ['Dorota', 'Brzezińska', '61-817', 'Gniezno', '506708056', '9129 6039 6844 6444', '36618.71', '46']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Dorora', 'Brjezińska', '62-817', '', '506708056', '9129 6039 68144 6444', '36618.71', '46']
# 993 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-814-org": rec-814-dup-2
#   Selected attribute for modification: surname
#     Selected corruptor: Categorial value
#       Original attribute value: 'Brzezińska'
#       Modified attribute value: 'Brzeziniski'
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '506708056'
#       Modified attribute value: ''
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '9129 6039 6844 6444'
#       Modified attribute value: '9129 6039 644 6444'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '61-817'
#       Modified attribute value: '61-717'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '46'
#       Modified attribute value: '64'
# Original record:
#   ['Dorota', 'Brzezińska', '61-817', 'Gniezno', '506708056', '9129 6039 6844 6444', '36618.71', '46']
# Record with 5 modified attributes
# (1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number, 1 in age-uniform,):
#   ['Dorota', 'Brzeziniski', '61-717', 'Gniezno', '', '9129 6039 644 6444', '36618.71', '64']
# 994 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-833-org"
#   Generate identifier for duplicate record based on "rec-833-org": rec-833-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Keybord value
#       Original attribute value: 'Kalisz'
#       Modified attribute value: 'Kaliaz'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0633 1617 0232 8051'
#       Modified attribute value: '0633 16178 0232 8051'
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Julia'
#       Modified attribute value: 'Ju|ia'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bednarska'
#       Modified attribute value: 'Bednaahska'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-236'
#       Modified attribute value: '60-246'
# Original record:
#   ['Julia', 'Bednarska', '60-236', 'Kalisz', '669718236', '0633 1617 0232 8051', '44497.05', '12']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Ju|ia', 'Bednaahska', '60-246', 'Kaliaz', '669718236', '0633 16178 0232 8051', '44497.05', '12']
# 995 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-833-org": rec-833-dup-1
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '669718236'
#       Modified attribute value: ''
#   Selected attribute for modification: income-normal
#     Selected corruptor: Missing value
#       Original attribute value: '44497.05'
#       Modified attribute value: ''
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Julia'
#       Modified attribute value: 'Julya'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bednarska'
#       Modified attribute value: 'Betnarska'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Kalisz'
#       Modified attribute value: 'Kalis'
# Original record:
#   ['Julia', 'Bednarska', '60-236', 'Kalisz', '669718236', '0633 1617 0232 8051', '44497.05', '12']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in city, 1 in telephone-number, 1 in income-normal,):
#   ['Julya', 'Betnarska', '60-236', 'Kalis', '', '0633 1617 0232 8051', '', '12']
# 996 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-680-org"
#   Generate identifier for duplicate record based on "rec-680-org": rec-680-dup-0
#   Selected attribute for modification: city
#     Selected corruptor: Edit operation
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Pqoznań'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Szymańska'
#       Modified attribute value: 'Szymańscka'
#   Selected attribute for modification: given-name
#     Selected corruptor: Keybord value
#       Original attribute value: 'Karina'
#       Modified attribute value: 'Karinz'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '62-800'
#       Modified attribute value: '62-80p'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1297 7607 0175 3358'
#       Modified attribute value: '1297 7607 015 3358'
# Original record:
#   ['Karina', 'Szymańska', '62-800', 'Poznań', '602356178', '1297 7607 0175 3358', '66385.52', '85']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Karinz', 'Szymańscka', '62-80p', 'Pqoznań', '602356178', '1297 7607 015 3358', '66385.52', '85']
# 997 of 1000 duplicate records generated so far
#
#
# Generating 2 modified (duplicate) records for record "rec-596-org"
#   Generate identifier for duplicate record based on "rec-596-org": rec-596-dup-0
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '609759545'
#       Modified attribute value: ''
#   Selected attribute for modification: given-name
#     Selected corruptor: OCR value
#       Original attribute value: 'Izabella'
#       Modified attribute value: 'Iza1>ella'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Krawczyk'
#       Modified attribute value: 'Krawkzyk'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0835 8471 9595 2021'
#       Modified attribute value: '0835 8471 595 2021'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '64-050'
#       Modified attribute value: '64-05o'
# Original record:
#   ['Izabella', 'Krawczyk', '64-050', 'Gniezno', '609759545', '0835 8471 9595 2021', '65653.28', '88']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in telephone-number, 1 in credit-card-number,):
#   ['Iza1>ella', 'Krawkzyk', '64-05o', 'Gniezno', '', '0835 8471 595 2021', '65653.28', '88']
# 998 of 1000 duplicate records generated so far
#
#   Generate identifier for duplicate record based on "rec-596-org": rec-596-dup-1
#   Selected attribute for modification: telephone-number
#     Selected corruptor: Missing value
#       Original attribute value: '609759545'
#       Modified attribute value: ''
#   Selected attribute for modification: surname
#     Selected corruptor: Keybord value
#       Original attribute value: 'Krawczyk'
#       Modified attribute value: 'Ktawczyk'
#   Selected attribute for modification: age-uniform
#     Selected corruptor: Edit operation
#       Original attribute value: '88'
#       Modified attribute value: '818'
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Izabella'
#       Modified attribute value: 'Izabela'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '0835 8471 9595 2021'
#       Modified attribute value: '0835 8471 95195 2021'
# Original record:
#   ['Izabella', 'Krawczyk', '64-050', 'Gniezno', '609759545', '0835 8471 9595 2021', '65653.28', '88']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in telephone-number, 1 in credit-card-number, 1 in age-uniform,):
#   ['Izabela', 'Ktawczyk', '64-050', 'Gniezno', '', '0835 8471 95195 2021', '65653.28', '818']
# 999 of 1000 duplicate records generated so far
#
#
# Generating 1 modified (duplicate) records for record "rec-677-org"
#   Generate identifier for duplicate record based on "rec-677-org": rec-677-dup-0
#   Selected attribute for modification: given-name
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Bernadeta'
#       Modified attribute value: 'Bernadeda'
#   Selected attribute for modification: surname
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Tomczak'
#       Modified attribute value: 'Tomczack'
#   Selected attribute for modification: credit-card-number
#     Selected corruptor: Edit operation
#       Original attribute value: '1313 4802 9938 1199'
#       Modified attribute value: '1313 4802 9938 13199'
#   Selected attribute for modification: city
#     Selected corruptor: Phonetic value
#       Original attribute value: 'Poznań'
#       Modified attribute value: 'Pojnań'
#   Selected attribute for modification: postcode
#     Selected corruptor: Keybord value
#       Original attribute value: '60-632'
#       Modified attribute value: '60-732'
# Original record:
#   ['Bernadeta', 'Tomczak', '60-632', 'Poznań', '450168094', '1313 4802 9938 1199', '38794.06', '86']
# Record with 5 modified attributes
# (1 in given-name, 1 in surname, 1 in postcode, 1 in city, 1 in credit-card-number,):
#   ['Bernadeda', 'Tomczack', '60-732', 'Pojnań', '450168094', '1313 4802 9938 13199', '38794.06', '86']
# 1000 of 1000 duplicate records generated so far

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/GECO3_CORRUPTION_RESULT.csv')
df.head(15)
# Out:
#             rec-id given-name      surname postcode     city  \
# 0     rec-0000-org    Eugenia   Baranowska   60-139  Gniezno
# 1     rec-0001-org   Julianna    Rutkowska   61-059   Poznań
# 2   rec-0002-dup-0    fecylia   Wajilewska   62-120      NaN
# 3     rec-0002-org    Cecylia   Wasilewska   62-120  Gniezno
# 4   rec-0003-dup-0   Lupomira       Góreka   6o-543   Poznań
# 5   rec-0003-dup-1   Lupomira       Góreka   60-543   Pojnań
# 6     rec-0003-org   Lubomira      Górecka   60-543   Poznań
# 7   rec-0004-dup-0   Wiejława      Zaadzka   60-76t   Poznań
# 8   rec-0004-dup-1    Wisława     Zaeadzka   60-765   Poznań
# 9     rec-0004-org   Wiesława     Zawadzka   60-765   Poznań
# 10    rec-0005-org     Joanna   Brzezińska   60-533   Poznań
# 11    rec-0006-org    Dioniza  Lewandowska   60-161   Kalisz
# 12    rec-0007-org     Dorota          Bąk   62-212    Konin
# 13  rec-0008-dup-0      Helka        Sjulc   62-456  Gniezno
# 14    rec-0008-org      Helga        Szulc   61-456  Gniezno
#
#     telephone-number    credit-card-number  income-normal  age-uniform
# 0        691416335.0   6758 5786 8463 8777       65161.02          1.0
# 1        508275539.0   4409 2995 3116 8176       37997.72         74.0
# 2                NaN  0109 48872 0693 7902       80722.63         37.0
# 3        539521117.0   0109 8872 0693 7902       80722.63         37.0
# 4                NaN  78737 8860 0534 8233       48330.41         35.0
# 5        576392086.0    7837 8860 05348233       48330.41         53.0
# 6        576392086.0   7837 8860 0534 8233       48330.41         35.0
# 7                NaN  4255 3067 87988 4307       47458.99         24.0
# 8                NaN    4255 3067 988 4307       47458.99         42.0
# 9        453691559.0   4255 3067 8988 4307       47458.99         24.0
# 10       536556472.0   9362 2149 9436 3745       88671.88         81.0
# 11       532270267.0   2204 8471 8749 5173       34330.80         79.0
# 12       792034717.0   5484 4257 5915 5904       69961.10         56.0
# 13               NaN   5819 5327 8364 7988            NaN         77.0
# 14       789399824.0   5819 5327 8364 7988       48024.23         77.0
